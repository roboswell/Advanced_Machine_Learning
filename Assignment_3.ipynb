# %% [markdown]
# # **Rob Boswell**
#
# # **Assignment 3: Projects in Advanced ML**
#
# https://github.com/roboswell/Advanced_Machine_Learning
#
# ---
#
#
# ---

# %% [markdown]
# ## **Data Source:**  Shahi, Gautam Kishore, Anne Dirkson, and Tim A. Majchrzak. "An exploratory study of covid-19 misinformation on twitter." Online Social Networks and Media 22 (2021): 100104.

# %% [markdown]
# ## Can you use the following data to build....?
# 1. A model with an embedding layer and dense layers (but w/ no layers meant for sequential data)
# 2.  A model using Conv1d Layers
# 3.  A model with one sequential layer (LSTM or GRU)
# 4. A model with stacked sequential layers (LSTM or GRU)
# 5. A model with bidirectional sequential layers
#
# ### After choosing a model, feed it some realistic tweets that are not from your training data to see if it returns meaningful/useful results.

# %% [markdown]
# ---
#
# **Question 1: Present examples of tweets from the dataset that demonstrate real information or misinformation.**
#
# ---
#
#
#
# ## The code below shows a summary of some real and fake COVID-19 tweets in the training set.

# %%
#Source:Fighting an Infodemic: COVID-19 Fake News Dataset, https://github.com/diptamath/covid_fake_news,https://arxiv.org/abs/2011.03327 

import pandas as pd
trainingdata=pd.read_csv("https://raw.githubusercontent.com/diptamath/covid_fake_news/main/data/Constraint_Train.csv", usecols = ['tweet','label'])
testdata=pd.read_csv("https://raw.githubusercontent.com/diptamath/covid_fake_news/main/data/english_test_with_labels.csv", usecols = ['tweet','label'])

trainingdata
# Out:
#                                                   tweet label
# 0     The CDC currently reports 99031 deaths. In gen...  real
# 1     States reported 1121 deaths a small rise from ...  real
# 2     Politically Correct Woman (Almost) Uses Pandem...  fake
# 3     #IndiaFightsCorona: We have 1524 #COVID testin...  real
# 4     Populous states can generate large case counts...  real
# ...                                                 ...   ...
# 6415  A tiger tested positive for COVID-19 please st...  fake
# 6416  ???Autopsies prove that COVID-19 is??� a blood...  fake
# 6417  _A post claims a COVID-19 vaccine has already ...  fake
# 6418  Aamir Khan Donate 250 Cr. In PM Relief Cares Fund  fake
# 6419  It has been 93 days since the last case of COV...  real
#
# [6420 rows x 2 columns]

# %% [markdown]
# ---
#
# **Question 2: Discuss the dataset in general terms and describe why building a predictive model using this data might be practically useful.  Who could benefit from a model like this? Explain.**
#
# ---
#
# ### **Answer:** The dataset contains 8,560 tweets that have previously been labelled as either "real" (i.e., true) or "fake" (i.e., incorrect/misleading). As seen from the results of the code below, there are 3,360 "real" tweets in the training set, and 1,120 in the test set. Further, there are 3,060 "fake" tweets in the training set, and 1,020 in the test set. Thus, 52% of the data are real tweets and 48% are fake tweets.
#
# ### Building a highly accurate and predictively strong model based on this data could be very beneficial for helping Twitter to identify and remove tweets that are misleading/false regarding COVID-19, and thus pose a strong potential health threat to viewers and those who they may communicate misinformation to others learned from such tweets.
#
# ### Monitoring when spikes in fake tweets are occuring by using such a model could also help health professionals with access to Twitter to know to move quickly to counter misinformation by speading accurrate tweets in hopes that far more Twitter users will be exposed to correct information about COVID-19 than fake information. Thus, both Twitter (the company) and the general population of not just Twitter users, but those with whom Twitter users share information about COVID-19 would stand to benefit from such a model.
#
# ---

# %%
print(len(trainingdata[trainingdata['label'] == 'real']))
print(len(testdata[testdata['label'] == 'real']))
# Out:
# 3360
# 1120

# %%
print(len(trainingdata[trainingdata['label'] == 'fake']))
print(len(testdata[testdata['label'] == 'fake']))
# Out:
# 3060
# 1020

# %% [markdown]
# ## Define Preprocessor

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=25000)
tokenizer.fit_on_texts(trainingdata.tweet)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen, max_words):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

# %% [markdown]
# ## Prepare Train and Test Data

# %%
# tokenize and pad X data
X_train = preprocessor(trainingdata.tweet, maxlen=45, max_words=25000)
X_test = preprocessor(testdata.tweet, maxlen=45, max_words=25000)

# ohe encode Y data
y_train = pd.get_dummies(trainingdata.label)
y_test = pd.get_dummies(testdata.label)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6420, 45)
# (2140, 45)

# %% [markdown]
# ## Model 1:

# %%
from tensorflow.keras.layers import Dense, Embedding,Flatten
from tensorflow.keras.layers import SimpleRNN, LSTM
from tensorflow.keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from tensorflow.python.keras.callbacks import ReduceLROnPlateau

# replace this model with the architectures from the task description
model = Sequential()
model.add(Embedding(25000, 32, input_length=45))
model.add(LSTM(32))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))

mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
red_lr= ReduceLROnPlateau(monitor='val_acc', patience=2,verbose=1,factor=0.05)

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

history = model.fit(X_train, y_train,
                    epochs=20,
                    batch_size=32,
                    callbacks=[mc,red_lr],
                    validation_split=0.2)
# Out:
# Epoch 1/20
# 161/161 [==============================] - 31s 11ms/step - loss: 0.4926 - acc: 0.7542 - val_loss: 0.2262 - val_acc: 0.9058
#
# Epoch 00001: val_acc improved from -inf to 0.90576, saving model to best_model.h5
# Epoch 2/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.1546 - acc: 0.9407 - val_loss: 0.1864 - val_acc: 0.9307
#
# Epoch 00002: val_acc improved from 0.90576 to 0.93069, saving model to best_model.h5
# Epoch 3/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0805 - acc: 0.9738 - val_loss: 0.2174 - val_acc: 0.9283
#
# Epoch 00003: val_acc did not improve from 0.93069
# Epoch 4/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0621 - acc: 0.9799 - val_loss: 0.1955 - val_acc: 0.9299
#
# Epoch 00004: val_acc did not improve from 0.93069
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 5/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0287 - acc: 0.9900 - val_loss: 0.2035 - val_acc: 0.9315
#
# Epoch 00005: val_acc improved from 0.93069 to 0.93146, saving model to best_model.h5
# Epoch 6/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0270 - acc: 0.9922 - val_loss: 0.2134 - val_acc: 0.9315
#
# Epoch 00006: val_acc did not improve from 0.93146
# Epoch 7/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0202 - acc: 0.9930 - val_loss: 0.2161 - val_acc: 0.9315
#
# Epoch 00007: val_acc did not improve from 0.93146
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.5000001187436284e-06.
# Epoch 8/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0222 - acc: 0.9929 - val_loss: 0.2167 - val_acc: 0.9307
#
# Epoch 00008: val_acc did not improve from 0.93146
# Epoch 9/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0244 - acc: 0.9932 - val_loss: 0.2172 - val_acc: 0.9307
#
# Epoch 00009: val_acc did not improve from 0.93146
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.2500000821091816e-07.
# Epoch 10/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0260 - acc: 0.9904 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00010: val_acc did not improve from 0.93146
# Epoch 11/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0203 - acc: 0.9929 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00011: val_acc did not improve from 0.93146
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 6.250000694763003e-09.
# Epoch 12/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0196 - acc: 0.9927 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00012: val_acc did not improve from 0.93146
# Epoch 13/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0187 - acc: 0.9949 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00013: val_acc did not improve from 0.93146
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.1250002585636594e-10.
# Epoch 14/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0210 - acc: 0.9936 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00014: val_acc did not improve from 0.93146
# Epoch 15/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0203 - acc: 0.9933 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00015: val_acc did not improve from 0.93146
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.5625001292818297e-11.
# Epoch 16/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0275 - acc: 0.9904 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00016: val_acc did not improve from 0.93146
# Epoch 17/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0257 - acc: 0.9924 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00017: val_acc did not improve from 0.93146
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 7.812500646409148e-13.
# Epoch 18/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0236 - acc: 0.9931 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00018: val_acc did not improve from 0.93146
# Epoch 19/20
# 161/161 [==============================] - 1s 8ms/step - loss: 0.0239 - acc: 0.9905 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00019: val_acc did not improve from 0.93146
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.906250323204574e-14.
# Epoch 20/20
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0232 - acc: 0.9928 - val_loss: 0.2173 - val_acc: 0.9307
#
# Epoch 00020: val_acc did not improve from 0.93146

# %% [markdown]
# ## Model 2:

# %%
from tensorflow.keras.layers import Bidirectional
import tensorflow as tf

with tf.device('/device:GPU:0'):
# replace this model with the architectures from the task description
  model = Sequential()
  model.add(Embedding(25000, 16, input_length=45))
  model.add(Bidirectional(LSTM(32, dropout=0.3, recurrent_dropout=0.3, return_sequences=True))) 
  model.add(Bidirectional(LSTM(32, dropout=0.3, recurrent_dropout=0.3, return_sequences=True)))
  model.add(Bidirectional(LSTM(32, dropout=0.3, recurrent_dropout=0.3)))  
  model.add(Flatten())
  model.add(Dense(2, activation='softmax'))

  mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
  red_lr= ReduceLROnPlateau(monitor='val_acc', patience=2,verbose=1,factor=0.1)

  model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

  history = model.fit(X_train, y_train,
                      epochs=10,
                      batch_size=16,
                      callbacks=[mc,red_lr],
                      validation_split=0.2)
# Out:
# Epoch 1/10
# 321/321 [==============================] - 69s 177ms/step - loss: 0.4327 - acc: 0.7902 - val_loss: 0.2116 - val_acc: 0.9097
#
# Epoch 00001: val_acc improved from -inf to 0.90966, saving model to best_model.h5
# Epoch 2/10
# 321/321 [==============================] - 55s 172ms/step - loss: 0.1496 - acc: 0.9408 - val_loss: 0.2323 - val_acc: 0.9237
#
# Epoch 00002: val_acc improved from 0.90966 to 0.92368, saving model to best_model.h5
# Epoch 3/10
# 321/321 [==============================] - 55s 172ms/step - loss: 0.0929 - acc: 0.9630 - val_loss: 0.2125 - val_acc: 0.9245
#
# Epoch 00003: val_acc improved from 0.92368 to 0.92445, saving model to best_model.h5
# Epoch 4/10
# 321/321 [==============================] - 56s 173ms/step - loss: 0.0787 - acc: 0.9717 - val_loss: 0.2052 - val_acc: 0.9307
#
# Epoch 00004: val_acc improved from 0.92445 to 0.93069, saving model to best_model.h5
# Epoch 5/10
# 321/321 [==============================] - 55s 172ms/step - loss: 0.0605 - acc: 0.9785 - val_loss: 0.2404 - val_acc: 0.9283
#
# Epoch 00005: val_acc did not improve from 0.93069
# Epoch 6/10
# 321/321 [==============================] - 56s 175ms/step - loss: 0.0452 - acc: 0.9862 - val_loss: 0.2161 - val_acc: 0.9291
#
# Epoch 00006: val_acc did not improve from 0.93069
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 7/10
# 321/321 [==============================] - 56s 174ms/step - loss: 0.0231 - acc: 0.9913 - val_loss: 0.2593 - val_acc: 0.9276
#
# Epoch 00007: val_acc did not improve from 0.93069
# Epoch 8/10
# 321/321 [==============================] - 55s 172ms/step - loss: 0.0256 - acc: 0.9917 - val_loss: 0.2642 - val_acc: 0.9276
#
# Epoch 00008: val_acc did not improve from 0.93069
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 9/10
# 321/321 [==============================] - 55s 172ms/step - loss: 0.0196 - acc: 0.9922 - val_loss: 0.2660 - val_acc: 0.9276
#
# Epoch 00009: val_acc did not improve from 0.93069
# Epoch 10/10
# 321/321 [==============================] - 56s 174ms/step - loss: 0.0254 - acc: 0.9910 - val_loss: 0.2675 - val_acc: 0.9276
#
# Epoch 00010: val_acc did not improve from 0.93069
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.

# %% [markdown]
# ## Model 3:

# %%
from tensorflow.keras import layers

with tf.device('/device:GPU:0'):
# replace this model with the architectures from the task description
  model = Sequential()
  model.add(layers.Embedding(25000, 150, input_length=45))
  model.add(layers.Conv1D(32, 7, activation='relu')) 
  model.add(layers.AveragePooling1D(5)) 
  model.add(layers.GRU(128, dropout=0.3, recurrent_dropout=0.3, return_sequences=True))
  model.add(layers.GRU(128, dropout=0.3, recurrent_dropout=0.3, return_sequences=True))
  model.add(layers.GRU(128, dropout=0.3, recurrent_dropout=0.3))  
  model.add(Flatten())
  model.add(layers.Dense(2, activation='softmax'))

  mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
  red_lr= ReduceLROnPlateau(monitor='val_acc', patience=2,verbose=1,factor=0.05)

  model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

  history = model.fit(X_train, y_train,
                      epochs=20,
                      batch_size=50,
                      callbacks=[mc,red_lr],
                      validation_split=0.2)
# Out:
# Epoch 1/20
# 103/103 [==============================] - 21s 119ms/step - loss: 0.4405 - acc: 0.7673 - val_loss: 0.2441 - val_acc: 0.9058
#
# Epoch 00001: val_acc improved from -inf to 0.90576, saving model to best_model.h5
# Epoch 2/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.1236 - acc: 0.9495 - val_loss: 0.2607 - val_acc: 0.9198
#
# Epoch 00002: val_acc improved from 0.90576 to 0.91978, saving model to best_model.h5
# Epoch 3/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0590 - acc: 0.9794 - val_loss: 0.2530 - val_acc: 0.9065
#
# Epoch 00003: val_acc did not improve from 0.91978
# Epoch 4/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0376 - acc: 0.9858 - val_loss: 0.3443 - val_acc: 0.9198
#
# Epoch 00004: val_acc did not improve from 0.91978
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 5/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0159 - acc: 0.9947 - val_loss: 0.3617 - val_acc: 0.9167
#
# Epoch 00005: val_acc did not improve from 0.91978
# Epoch 6/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0158 - acc: 0.9949 - val_loss: 0.3731 - val_acc: 0.9167
#
# Epoch 00006: val_acc did not improve from 0.91978
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 2.5000001187436284e-06.
# Epoch 7/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0097 - acc: 0.9968 - val_loss: 0.3737 - val_acc: 0.9167
#
# Epoch 00007: val_acc did not improve from 0.91978
# Epoch 8/20
# 103/103 [==============================] - 11s 111ms/step - loss: 0.0143 - acc: 0.9949 - val_loss: 0.3741 - val_acc: 0.9174
#
# Epoch 00008: val_acc did not improve from 0.91978
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.2500000821091816e-07.
# Epoch 9/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0120 - acc: 0.9958 - val_loss: 0.3741 - val_acc: 0.9174
#
# Epoch 00009: val_acc did not improve from 0.91978
# Epoch 10/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0080 - acc: 0.9976 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00010: val_acc did not improve from 0.91978
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.250000694763003e-09.
# Epoch 11/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0135 - acc: 0.9952 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00011: val_acc did not improve from 0.91978
# Epoch 12/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0115 - acc: 0.9965 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00012: val_acc did not improve from 0.91978
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.1250002585636594e-10.
# Epoch 13/20
# 103/103 [==============================] - 11s 110ms/step - loss: 0.0153 - acc: 0.9945 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00013: val_acc did not improve from 0.91978
# Epoch 14/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0094 - acc: 0.9967 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00014: val_acc did not improve from 0.91978
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.5625001292818297e-11.
# Epoch 15/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0093 - acc: 0.9972 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00015: val_acc did not improve from 0.91978
# Epoch 16/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0137 - acc: 0.9961 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00016: val_acc did not improve from 0.91978
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 7.812500646409148e-13.
# Epoch 17/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0141 - acc: 0.9949 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00017: val_acc did not improve from 0.91978
# Epoch 18/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0087 - acc: 0.9979 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00018: val_acc did not improve from 0.91978
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.906250323204574e-14.
# Epoch 19/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0113 - acc: 0.9962 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00019: val_acc did not improve from 0.91978
# Epoch 20/20
# 103/103 [==============================] - 11s 109ms/step - loss: 0.0140 - acc: 0.9950 - val_loss: 0.3742 - val_acc: 0.9174
#
# Epoch 00020: val_acc did not improve from 0.91978
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.9531251616022873e-15.

# %% [markdown]
# ## Model 4:

# %%
from tensorflow.keras import layers

with tf.device('/device:GPU:0'):
# replace this model with the architectures from the task description
  model = Sequential()
  model.add(layers.Embedding(25000, 50, input_length=45))
  model.add(layers.Conv1D(60, 5, activation='relu')) 
  model.add(layers.AveragePooling1D(3)) 
  model.add(layers.GRU(128, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))
  model.add(layers.GRU(128, dropout=0.2, recurrent_dropout=0.2))  
  model.add(Flatten())
  model.add(layers.Dense(2, activation='softmax'))

  mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
  red_lr= ReduceLROnPlateau(monitor='val_acc', patience=2,verbose=1,factor=0.05)

  model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

  history = model.fit(X_train, y_train,
                      epochs=20,
                      batch_size=20,
                      callbacks=[mc,red_lr],
                      validation_split=0.2)
# Out:
# Epoch 1/20
# 257/257 [==============================] - 26s 79ms/step - loss: 0.4037 - acc: 0.7915 - val_loss: 0.2155 - val_acc: 0.9128
#
# Epoch 00001: val_acc improved from -inf to 0.91277, saving model to best_model.h5
# Epoch 2/20
# 257/257 [==============================] - 20s 76ms/step - loss: 0.1264 - acc: 0.9498 - val_loss: 0.1863 - val_acc: 0.9330
#
# Epoch 00002: val_acc improved from 0.91277 to 0.93302, saving model to best_model.h5
# Epoch 3/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0675 - acc: 0.9785 - val_loss: 0.1922 - val_acc: 0.9260
#
# Epoch 00003: val_acc did not improve from 0.93302
# Epoch 4/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0444 - acc: 0.9846 - val_loss: 0.2375 - val_acc: 0.9245
#
# Epoch 00004: val_acc did not improve from 0.93302
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 5/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0251 - acc: 0.9917 - val_loss: 0.2687 - val_acc: 0.9276
#
# Epoch 00005: val_acc did not improve from 0.93302
# Epoch 6/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0182 - acc: 0.9934 - val_loss: 0.2860 - val_acc: 0.9268
#
# Epoch 00006: val_acc did not improve from 0.93302
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 2.5000001187436284e-06.
# Epoch 7/20
# 257/257 [==============================] - 20s 76ms/step - loss: 0.0258 - acc: 0.9908 - val_loss: 0.2863 - val_acc: 0.9276
#
# Epoch 00007: val_acc did not improve from 0.93302
# Epoch 8/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0236 - acc: 0.9905 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00008: val_acc did not improve from 0.93302
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.2500000821091816e-07.
# Epoch 9/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0172 - acc: 0.9942 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00009: val_acc did not improve from 0.93302
# Epoch 10/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0244 - acc: 0.9902 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00010: val_acc did not improve from 0.93302
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.250000694763003e-09.
# Epoch 11/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0231 - acc: 0.9923 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00011: val_acc did not improve from 0.93302
# Epoch 12/20
# 257/257 [==============================] - 20s 78ms/step - loss: 0.0246 - acc: 0.9921 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00012: val_acc did not improve from 0.93302
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.1250002585636594e-10.
# Epoch 13/20
# 257/257 [==============================] - 19s 76ms/step - loss: 0.0199 - acc: 0.9934 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00013: val_acc did not improve from 0.93302
# Epoch 14/20
# 257/257 [==============================] - 19s 75ms/step - loss: 0.0194 - acc: 0.9927 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00014: val_acc did not improve from 0.93302
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.5625001292818297e-11.
# Epoch 15/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0216 - acc: 0.9912 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00015: val_acc did not improve from 0.93302
# Epoch 16/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0194 - acc: 0.9927 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00016: val_acc did not improve from 0.93302
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 7.812500646409148e-13.
# Epoch 17/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0207 - acc: 0.9945 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00017: val_acc did not improve from 0.93302
# Epoch 18/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0179 - acc: 0.9934 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00018: val_acc did not improve from 0.93302
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.906250323204574e-14.
# Epoch 19/20
# 257/257 [==============================] - 20s 77ms/step - loss: 0.0185 - acc: 0.9934 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00019: val_acc did not improve from 0.93302
# Epoch 20/20
# 257/257 [==============================] - 20s 76ms/step - loss: 0.0260 - acc: 0.9906 - val_loss: 0.2869 - val_acc: 0.9276
#
# Epoch 00020: val_acc did not improve from 0.93302
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.9531251616022873e-15.

# %% [markdown]
# ## Model 5:

# %%
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dense, Embedding,Flatten
from tensorflow.keras.layers import SimpleRNN, LSTM
from tensorflow.keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from tensorflow.python.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Bidirectional
import tensorflow as tf


with tf.device('/device:GPU:0'):

  model = Sequential()
  model.add(Embedding(25000, 26, input_length=45))
  model.add(Bidirectional(LSTM(128, dropout=0.15, recurrent_dropout=0.15, return_sequences=True))) 
  model.add(Bidirectional(LSTM(128, dropout=0.15, recurrent_dropout=0.15, return_sequences=True)))
  model.add(Bidirectional(GRU(32, dropout=0.15, recurrent_dropout=0.15, return_sequences=True)))
  model.add(Bidirectional(GRU(32, dropout=0.15, recurrent_dropout=0.15)))  
  model.add(Flatten())
  model.add(Dense(2, activation='softmax'))

  mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
  red_lr= ReduceLROnPlateau(monitor='val_acc', patience=2, verbose=1, factor=0.05)

  model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

  history = model.fit(X_train, y_train,
                      epochs=10,
                      batch_size=32,
                      callbacks=[mc,red_lr],
                      validation_split=0.2)
# Out:
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/10
# 161/161 [==============================] - 198s 1s/step - loss: 0.4762 - acc: 0.7778 - val_loss: 0.2039 - val_acc: 0.9151
#
# Epoch 00001: val_acc improved from -inf to 0.91511, saving model to best_model.h5
# Epoch 2/10
# 161/161 [==============================] - 180s 1s/step - loss: 0.1599 - acc: 0.9380 - val_loss: 0.2000 - val_acc: 0.9221
#
# Epoch 00002: val_acc improved from 0.91511 to 0.92212, saving model to best_model.h5
# Epoch 3/10
# 161/161 [==============================] - 178s 1s/step - loss: 0.0760 - acc: 0.9725 - val_loss: 0.1914 - val_acc: 0.9385
#
# Epoch 00003: val_acc improved from 0.92212 to 0.93847, saving model to best_model.h5
# Epoch 4/10
# 161/161 [==============================] - 178s 1s/step - loss: 0.0542 - acc: 0.9841 - val_loss: 0.2356 - val_acc: 0.9221
#
# Epoch 00004: val_acc did not improve from 0.93847
# Epoch 5/10
# 161/161 [==============================] - 179s 1s/step - loss: 0.0218 - acc: 0.9932 - val_loss: 0.3656 - val_acc: 0.9299
#
# Epoch 00005: val_acc did not improve from 0.93847
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 6/10
# 161/161 [==============================] - 181s 1s/step - loss: 0.0139 - acc: 0.9962 - val_loss: 0.3102 - val_acc: 0.9322
#
# Epoch 00006: val_acc did not improve from 0.93847
# Epoch 7/10
# 161/161 [==============================] - 177s 1s/step - loss: 0.0091 - acc: 0.9974 - val_loss: 0.3077 - val_acc: 0.9322
#
# Epoch 00007: val_acc did not improve from 0.93847
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.5000001187436284e-06.
# Epoch 8/10
# 161/161 [==============================] - 176s 1s/step - loss: 0.0068 - acc: 0.9980 - val_loss: 0.3082 - val_acc: 0.9322
#
# Epoch 00008: val_acc did not improve from 0.93847
# Epoch 9/10
# 161/161 [==============================] - 177s 1s/step - loss: 0.0082 - acc: 0.9980 - val_loss: 0.3089 - val_acc: 0.9322
#
# Epoch 00009: val_acc did not improve from 0.93847
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.2500000821091816e-07.
# Epoch 10/10
# 161/161 [==============================] - 178s 1s/step - loss: 0.0049 - acc: 0.9986 - val_loss: 0.3090 - val_acc: 0.9322
#
# Epoch 00010: val_acc did not improve from 0.93847

# %% [markdown]
# ## **Question:** Discuss which models performed better and point out relevant hyper-parameter values for successful models.
#
# ## **Answer:** My 5th model performed the best (93.847% validation accuracy). I describe in more detail below the specifics of the 5th model. It combined two SLTM layers (each having 128 neurons) with two GRU layers (each having 32 neurons). This model (and in fact, all of my models) had embeddings; in my 5th model, the embedding layer contained 26 attributes. I also used dropout (.15) and recurrent dropout (.15) to try to reduce overfitting. It is possible that lower percentage for dropout compared to my other models may have contributed towards the higher accuracy rate, although normally the opposite might be expected.
#
# ## My fourth model was my second highest performing model, with validation accuracy reaching 93.302%. It had a max_words value of 25,000 (as did model 5), but had 50 embedding attributes. It appears that a smaller number of embedded attributes in the case of this data may contribute to higher validation accuracy. I used a conv1d layer of size 5 x 5 and average pooling of size 3 x 3 to shrink down parameters before applying stacking with two GRU layers having 128 neurons each. I also used dropout (.2) and recurrent dropout (.2) for both GRU layers.
#
# ## I will lastly touch on the details of my worst performing model, model 3, which only achieved a validation accuracy of 91.978%. It also had a max_words value of 25,000 and input_length value of 45, and used conv1d (32 filters of size 7x7) and average pooling of size 5x5 to decrease the number of parameters before stacking. I then included 3 GRU layers back to back - each having 128 neurons and dropout (0.30) and recurrent dropout (0.30). It is noteable that the larger number of stacked layers, larger number of neurons per layer, and larger proportion of nuerons experiencing dropout did not result in higher accuracy. This may suggest that with this dataset simpler models perform better. Bigger is not always better.

# %%
# format y_pred as labels 
y_pred = model.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:5]
# Out:
# ['real', 'fake', 'fake', 'real', 'real']

# %% [markdown]
# ## Submitting My Best Model (Model 5)

# %%
# install aimodelshare library
# %%capture
! pip install aimodelshare --upgrade --extra-index-url https://test.pypi.org/simple/

# %%
import aimodelshare as ai
from aimodelshare.aimsonnx import model_to_onnx

# %%
# save preprocessor
ai.export_preprocessor(preprocessor,"")

# %%
# save model in onnx format
onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("onnx_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# INFO:tensorflow:Assets written to: /tmp/assets

# %%
# set credentials for modeltoapi function 
# make sure you have uploaded your credentials.txt file
from aimodelshare.aws import set_credentials
api_url = "https://wvr23l2z9i.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=api_url,credential_file="credentials.txt", type="submit_model", manual=False)
# Out:
# AI Model Share login credentials set successfully.
# AWS credentials set successfully.

# %%
# submit model and predictions to competition
ai.submit_model("onnx_model.onnx",
                api_url,
                prediction_submission=predicted_labels,
                preprocessor="preprocessor.zip")
# Out:
# 'Your model has been submitted as model version 75'

# %%
# check leaderboard
data=ai.get_leaderboard(api_url, verbose=3)
ai.leaderboard.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col0,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col1,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col2,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col3,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col4,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col5,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col6,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col7,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col8,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col9,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col10,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col11,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col12,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col13,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col14,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col15,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col16,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col17,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col18,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col19,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col20,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col21,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col22,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col23,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col24,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col25,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col26,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row0_col27,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col4,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col5,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col6,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col7,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col8,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col9,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col10,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col11,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col12,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col13,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col14,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col15,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col16,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col17,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col18,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col19,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col20,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col21,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col22,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col23,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col24,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col25,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col26,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row1_col27,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col4,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col5,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col6,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col7,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col8,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col9,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col10,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col11,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col12,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col13,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col14,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col15,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col16,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col17,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col18,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col19,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col20,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col21,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col22,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col23,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col24,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col25,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col26,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row2_col27,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col4,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col5,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col6,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col7,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col8,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col9,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col10,#T_cb06f396_a00c_11eb_b49e_0242ac1c0002row3_col11,#T_cb06f396_a00 ...

# %%
 # Get best model architecture and view model summary, change version arg as needed
 
 bestmodel = ai.aimsonnx.instantiate_model(api_url, version=66) 

 bestmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 60, 16)            160000
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1922
# =================================================================
# Total params: 161,922
# Trainable params: 161,922
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compare two model versions to see diffs
ai.aimsonnx.compare_models(api_url, version_list=[66,75])
# Out:
# <style  type="text/css" >
# #T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row2_col0,#T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row6_col3{
#             background:  tomato;
#         }</style><table id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model_66_Layer</th>        <th class="col_heading level0 col1" >Model_66_Shape</th>        <th class="col_heading level0 col2" >Model_66_Params</th>        <th class="col_heading level0 col3" >Model_75_Layer</th>        <th class="col_heading level0 col4" >Model_75_Shape</th>        <th class="col_heading level0 col5" >Model_75_Params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row0_col0" class="data row0 col0" >Embedding</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row0_col1" class="data row0 col1" >(None, 60, 16)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row0_col2" class="data row0 col2" >160000.000000</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row0_col3" class="data row0 col3" >Embedding</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row0_col4" class="data row0 col4" >(None, 45, 26)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row0_col5" class="data row0 col5" >650000</td>
#             </tr>
#             <tr>
#                         <th id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row1_col0" class="data row1 col0" >Flatten</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row1_col1" class="data row1 col1" >(None, 960)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row1_col3" class="data row1 col3" >Bidirectional</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row1_col4" class="data row1 col4" >(None, 45, 256)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row1_col5" class="data row1 col5" >158720</td>
#             </tr>
#             <tr>
#                         <th id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row2_col0" class="data row2 col0" >Dense</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row2_col1" class="data row2 col1" >(None, 2)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row2_col2" class="data row2 col2" >1922.000000</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row2_col3" class="data row2 col3" >Bidirectional</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row2_col4" class="data row2 col4" >(None, 45, 256)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row2_col5" class="data row2 col5" >394240</td>
#             </tr>
#             <tr>
#                         <th id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row3_col3" class="data row3 col3" >Bidirectional</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row3_col4" class="data row3 col4" >(None, 45, 64)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row3_col5" class="data row3 col5" >55680</td>
#             </tr>
#             <tr>
#                         <th id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row4_col0" class="data row4 col0" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row4_col1" class="data row4 col1" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row4_col2" class="data row4 col2" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row4_col3" class="data row4 col3" >Bidirectional</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row4_col4" class="data row4 col4" >(None, 64)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row4_col5" class="data row4 col5" >18816</td>
#             </tr>
#             <tr>
#                         <th id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row5_col0" class="data row5 col0" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row5_col2" class="data row5 col2" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row5_col3" class="data row5 col3" >Flatten</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row5_col4" class="data row5 col4" >(None, 64)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row5_col5" class="data row5 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row6_col0" class="data row6 col0" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row6_col1" class="data row6 col1" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row6_col2" class="data row6 col2" >nan</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row6_col3" class="data row6 col3" >Dense</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row6_col4" class="data row6 col4" >(None, 2)</td>
#                         <td id="T_7c3e0de8_a00d_11eb_b49e_0242ac1c0002row6_col5" class="data row6 col5" >130</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # **Question: Explain how the [best] model's structure is different from your best model.**
#
#
#
# ---
#
# ### **Answer:** I have printed the keras model.summary() (as well as compare_models() ) above. The best model (version 66) is different in several ways from my model (version 75). It does not use bidirectional networks, and does not use stacking, unlike my model. Rather, it only uses embedding according to both model.summary() and compare_models(). Whereas my model has maxlen = 45, the best model has maxlen=60. While my model used an embedding size of 26 attributes, the best model in the class used 16. As a result, my model started with a lot more parameters (650,000) compared to the best model (160,000).  This starting parameter value means that they used a max_words value of 160,000/60 = 10,000, whereas my model had a max_words value of 25,000.
#
# ### Although compare_models() above says that my first two layers had 256 neurons, and that my last 2 layers had 64 neurons each, this is incorrect. My 4 layers had 128, 128, 32 and 32 neurons, respectively. The function evidently doubles the true number of neurons in each layer.
#
# ---

# %% [markdown]
# # **Question:** Fit the best model from the leader board to training data and evaluate it on test data to complete your report.
#
# # Complete your report by feeding your model some realistic tweets to see if it returns meaningful/useful results (these tweets can be found online or you can create them yourself).
#
# ---
#
# ### **Answer:** First, I will reconstruct the best model, training and testing it on the same data used for my models above. Then I will test it on 10 immitation tweets that I designed, to see how accurately the model can predict them.

# %% [markdown]
# ## Define Preprocessor

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(trainingdata.tweet)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen, max_words):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

# %%
# tokenize and pad X data
X_train = preprocessor(trainingdata.tweet, maxlen=60, max_words=10000)
X_test = preprocessor(testdata.tweet, maxlen=60, max_words=10000)

# ohe encode Y data
y_train = pd.get_dummies(trainingdata.label)
y_test = pd.get_dummies(testdata.label)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6420, 60)
# (2140, 60)

# %%
from tensorflow.keras.layers import GRU

with tf.device('/device:GPU:0'):
# replace this model with the architectures from the task description
  model = Sequential()
  model.add(Embedding(10000, 16, input_length=60))
  model.add(Flatten())
  model.add(Dense(2, activation='softmax'))

  mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
  red_lr= ReduceLROnPlateau(monitor='val_acc', patience=2, verbose=1,factor=0.05)

  model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

  history = model.fit(X_train, y_train,
                      epochs=100,
                      batch_size=30,
                      callbacks=[mc,red_lr],
                      validation_split=0.2)
# Out:
# Epoch 1/100
# 172/172 [==============================] - 1s 4ms/step - loss: 0.5694 - acc: 0.7184 - val_loss: 0.3761 - val_acc: 0.8326
#
# Epoch 00001: val_acc improved from -inf to 0.83255, saving model to best_model.h5
# Epoch 2/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.3145 - acc: 0.8656 - val_loss: 0.2587 - val_acc: 0.8863
#
# Epoch 00002: val_acc improved from 0.83255 to 0.88629, saving model to best_model.h5
# Epoch 3/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.1905 - acc: 0.9307 - val_loss: 0.2061 - val_acc: 0.9174
#
# Epoch 00003: val_acc improved from 0.88629 to 0.91745, saving model to best_model.h5
# Epoch 4/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.1356 - acc: 0.9512 - val_loss: 0.1831 - val_acc: 0.9307
#
# Epoch 00004: val_acc improved from 0.91745 to 0.93069, saving model to best_model.h5
# Epoch 5/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0939 - acc: 0.9719 - val_loss: 0.1746 - val_acc: 0.9276
#
# Epoch 00005: val_acc did not improve from 0.93069
# Epoch 6/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0791 - acc: 0.9701 - val_loss: 0.1682 - val_acc: 0.9315
#
# Epoch 00006: val_acc improved from 0.93069 to 0.93146, saving model to best_model.h5
# Epoch 7/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0571 - acc: 0.9806 - val_loss: 0.1632 - val_acc: 0.9369
#
# Epoch 00007: val_acc improved from 0.93146 to 0.93692, saving model to best_model.h5
# Epoch 8/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0470 - acc: 0.9840 - val_loss: 0.1649 - val_acc: 0.9330
#
# Epoch 00008: val_acc did not improve from 0.93692
# Epoch 9/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0353 - acc: 0.9903 - val_loss: 0.1658 - val_acc: 0.9338
#
# Epoch 00009: val_acc did not improve from 0.93692
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 10/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0275 - acc: 0.9930 - val_loss: 0.1641 - val_acc: 0.9361
#
# Epoch 00010: val_acc did not improve from 0.93692
# Epoch 11/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0297 - acc: 0.9909 - val_loss: 0.1643 - val_acc: 0.9385
#
# Epoch 00011: val_acc improved from 0.93692 to 0.93847, saving model to best_model.h5
# Epoch 12/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0246 - acc: 0.9942 - val_loss: 0.1647 - val_acc: 0.9393
#
# Epoch 00012: val_acc improved from 0.93847 to 0.93925, saving model to best_model.h5
# Epoch 13/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0259 - acc: 0.9925 - val_loss: 0.1649 - val_acc: 0.9393
#
# Epoch 00013: val_acc did not improve from 0.93925
# Epoch 14/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0238 - acc: 0.9933 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00014: val_acc did not improve from 0.93925
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.5000001187436284e-06.
# Epoch 15/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0286 - acc: 0.9917 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00015: val_acc did not improve from 0.93925
# Epoch 16/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0232 - acc: 0.9948 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00016: val_acc did not improve from 0.93925
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.2500000821091816e-07.
# Epoch 17/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0305 - acc: 0.9902 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00017: val_acc did not improve from 0.93925
# Epoch 18/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0254 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00018: val_acc did not improve from 0.93925
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.250000694763003e-09.
# Epoch 19/100
# 172/172 [==============================] - 1s 8ms/step - loss: 0.0270 - acc: 0.9925 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00019: val_acc did not improve from 0.93925
# Epoch 20/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0268 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00020: val_acc did not improve from 0.93925
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.1250002585636594e-10.
# Epoch 21/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0250 - acc: 0.9943 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00021: val_acc did not improve from 0.93925
# Epoch 22/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0246 - acc: 0.9936 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00022: val_acc did not improve from 0.93925
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.5625001292818297e-11.
# Epoch 23/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0275 - acc: 0.9923 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00023: val_acc did not improve from 0.93925
# Epoch 24/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0285 - acc: 0.9920 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00024: val_acc did not improve from 0.93925
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 7.812500646409148e-13.
# Epoch 25/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0262 - acc: 0.9921 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00025: val_acc did not improve from 0.93925
# Epoch 26/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0266 - acc: 0.9914 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00026: val_acc did not improve from 0.93925
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 3.906250323204574e-14.
# Epoch 27/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0235 - acc: 0.9945 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00027: val_acc did not improve from 0.93925
# Epoch 28/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0230 - acc: 0.9940 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00028: val_acc did not improve from 0.93925
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.9531251616022873e-15.
# Epoch 29/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0265 - acc: 0.9925 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00029: val_acc did not improve from 0.93925
# Epoch 30/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0263 - acc: 0.9923 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00030: val_acc did not improve from 0.93925
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.765626019769673e-17.
# Epoch 31/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0250 - acc: 0.9923 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00031: val_acc did not improve from 0.93925
# Epoch 32/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0277 - acc: 0.9918 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00032: val_acc did not improve from 0.93925
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.882813076059286e-18.
# Epoch 33/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0254 - acc: 0.9921 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00033: val_acc did not improve from 0.93925
# Epoch 34/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0231 - acc: 0.9931 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00034: val_acc did not improve from 0.93925
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 2.441406620747704e-19.
# Epoch 35/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0247 - acc: 0.9938 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00035: val_acc did not improve from 0.93925
# Epoch 36/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0289 - acc: 0.9921 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00036: val_acc did not improve from 0.93925
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.2207032586750637e-20.
# Epoch 37/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0278 - acc: 0.9927 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00037: val_acc did not improve from 0.93925
# Epoch 38/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0263 - acc: 0.9933 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00038: val_acc did not improve from 0.93925
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 6.103516131816605e-22.
# Epoch 39/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0282 - acc: 0.9919 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00039: val_acc did not improve from 0.93925
# Epoch 40/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0258 - acc: 0.9931 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00040: val_acc did not improve from 0.93925
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.051758015421205e-23.
# Epoch 41/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0296 - acc: 0.9911 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00041: val_acc did not improve from 0.93925
# Epoch 42/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0255 - acc: 0.9942 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00042: val_acc did not improve from 0.93925
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.5258789761561661e-24.
# Epoch 43/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0260 - acc: 0.9933 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00043: val_acc did not improve from 0.93925
# Epoch 44/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0261 - acc: 0.9931 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00044: val_acc did not improve from 0.93925
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 7.629394782173217e-26.
# Epoch 45/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0244 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00045: val_acc did not improve from 0.93925
# Epoch 46/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0277 - acc: 0.9917 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00046: val_acc did not improve from 0.93925
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 3.814697452716367e-27.
# Epoch 47/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0257 - acc: 0.9928 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00047: val_acc did not improve from 0.93925
# Epoch 48/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0257 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00048: val_acc did not improve from 0.93925
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.9073487648767824e-28.
# Epoch 49/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0255 - acc: 0.9931 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00049: val_acc did not improve from 0.93925
# Epoch 50/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0326 - acc: 0.9882 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00050: val_acc did not improve from 0.93925
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 9.536744065125155e-30.
# Epoch 51/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0267 - acc: 0.9915 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00051: val_acc did not improve from 0.93925
# Epoch 52/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0241 - acc: 0.9937 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00052: val_acc did not improve from 0.93925
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 4.768371957330939e-31.
# Epoch 53/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0231 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00053: val_acc did not improve from 0.93925
# Epoch 54/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0244 - acc: 0.9935 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00054: val_acc did not improve from 0.93925
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 2.3841860727050176e-32.
# Epoch 55/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0251 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00055: val_acc did not improve from 0.93925
# Epoch 56/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0235 - acc: 0.9946 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00056: val_acc did not improve from 0.93925
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1.1920930657398675e-33.
# Epoch 57/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0272 - acc: 0.9912 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00057: val_acc did not improve from 0.93925
# Epoch 58/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0250 - acc: 0.9937 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00058: val_acc did not improve from 0.93925
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 5.960465328699338e-35.
# Epoch 59/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0272 - acc: 0.9918 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00059: val_acc did not improve from 0.93925
# Epoch 60/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0228 - acc: 0.9948 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00060: val_acc did not improve from 0.93925
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 2.9802326069524836e-36.
# Epoch 61/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0267 - acc: 0.9929 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00061: val_acc did not improve from 0.93925
# Epoch 62/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0248 - acc: 0.9931 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00062: val_acc did not improve from 0.93925
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 1.490116303476242e-37.
# Epoch 63/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0250 - acc: 0.9937 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00063: val_acc did not improve from 0.93925
# Epoch 64/100
# 172/172 [==============================] - 0s 3ms/step - loss: 0.0265 - acc: 0.9922 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00064: val_acc did not improve from 0.93925
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 7.450581741588964e-39.
# Epoch 65/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0254 - acc: 0.9919 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00065: val_acc did not improve from 0.93925
# Epoch 66/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0254 - acc: 0.9937 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00066: val_acc did not improve from 0.93925
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 3.725291010924328e-40.
# Epoch 67/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0247 - acc: 0.9933 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00067: val_acc did not improve from 0.93925
# Epoch 68/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0251 - acc: 0.9938 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00068: val_acc did not improve from 0.93925
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.8626479577344767e-41.
# Epoch 69/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0270 - acc: 0.9932 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00069: val_acc did not improve from 0.93925
# Epoch 70/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0243 - acc: 0.9944 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00070: val_acc did not improve from 0.93925
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 9.313029593902735e-43.
# Epoch 71/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0267 - acc: 0.9912 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00071: val_acc did not improve from 0.93925
# Epoch 72/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0244 - acc: 0.9940 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00072: val_acc did not improve from 0.93925
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 4.659317393880017e-44.
# Epoch 73/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0247 - acc: 0.9936 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00073: val_acc did not improve from 0.93925
# Epoch 74/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0243 - acc: 0.9937 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00074: val_acc did not improve from 0.93925
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 2.3121424661359484e-45.
# Epoch 75/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0258 - acc: 0.9914 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00075: val_acc did not improve from 0.93925
# Epoch 76/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0250 - acc: 0.9916 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00076: val_acc did not improve from 0.93925
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 1.4012984643248171e-46.
# Epoch 77/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0269 - acc: 0.9932 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00077: val_acc did not improve from 0.93925
# Epoch 78/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0248 - acc: 0.9939 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00078: val_acc did not improve from 0.93925
# Epoch 79/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0259 - acc: 0.9937 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00079: val_acc did not improve from 0.93925
# Epoch 80/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0244 - acc: 0.9934 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00080: val_acc did not improve from 0.93925
# Epoch 81/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0231 - acc: 0.9931 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00081: val_acc did not improve from 0.93925
# Epoch 82/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0275 - acc: 0.9934 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00082: val_acc did not improve from 0.93925
# Epoch 83/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0270 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00083: val_acc did not improve from 0.93925
# Epoch 84/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0242 - acc: 0.9935 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00084: val_acc did not improve from 0.93925
# Epoch 85/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0289 - acc: 0.9908 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00085: val_acc did not improve from 0.93925
# Epoch 86/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0260 - acc: 0.9932 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00086: val_acc did not improve from 0.93925
# Epoch 87/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0269 - acc: 0.9914 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00087: val_acc did not improve from 0.93925
# Epoch 88/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0255 - acc: 0.9925 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00088: val_acc did not improve from 0.93925
# Epoch 89/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0242 - acc: 0.9940 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00089: val_acc did not improve from 0.93925
# Epoch 90/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0272 - acc: 0.9920 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00090: val_acc did not improve from 0.93925
# Epoch 91/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0262 - acc: 0.9938 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00091: val_acc did not improve from 0.93925
# Epoch 92/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0270 - acc: 0.9922 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00092: val_acc did not improve from 0.93925
# Epoch 93/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0275 - acc: 0.9919 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00093: val_acc did not improve from 0.93925
# Epoch 94/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0245 - acc: 0.9943 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00094: val_acc did not improve from 0.93925
# Epoch 95/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0279 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00095: val_acc did not improve from 0.93925
# Epoch 96/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0245 - acc: 0.9939 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00096: val_acc did not improve from 0.93925
# Epoch 97/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0287 - acc: 0.9918 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00097: val_acc did not improve from 0.93925
# Epoch 98/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0292 - acc: 0.9928 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00098: val_acc did not improve from 0.93925
# Epoch 99/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0235 - acc: 0.9930 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00099: val_acc did not improve from 0.93925
# Epoch 100/100
# 172/172 [==============================] - 1s 3ms/step - loss: 0.0239 - acc: 0.9933 - val_loss: 0.1649 - val_acc: 0.9377
#
# Epoch 00100: val_acc did not improve from 0.93925

# %% [markdown]
# ### **Answer a):** Based on the train and test set provided for this assignment, it appears that the best model only achieves a validation accuracy score of 93.93%, at least when I set the batch_size equal to 30.

# %% [markdown]
# ### **Answer b):**
#
# ### As seen below, I have created a series of tweets (5 real and 5 fake). My results are described further below the following code:

# %%
# Fake example #1

print(model.predict(preprocessor(["COVID is fake news. It's nothing more than the common flu. This is just anti-Trump propoganda from the Radical Left."], maxlen=60, max_words=10000)))
# Out:
# [[9.99988317e-01 1.16371575e-05]]

# %%
# Fake example #2

print(model.predict(preprocessor(["COVID-19 is no more deadly than the flu. Don't believe what the 'experts' are telling you. Don't wear a mask if you don't feel like it!"], maxlen=60, max_words=10000)))
# Out:
# [[9.991449e-01 8.550276e-04]]

# %%
# Fake example #3

print(model.predict(preprocessor(["Don't let the Antifa radicals convince you that COVID is dangerous. They just want to destroy our economy by making people stay home so that they can steal the election."], maxlen=60, max_words=10000)))
# Out:
# [[9.9931133e-01 6.8871636e-04]]

# %%
# Fake example #4

print(model.predict(preprocessor(["COVID-19 is China's attempt to take over the world. They have been developing biological weapons for decades to unleash on the US. They will kill their own people to do it if necessary."], maxlen=60, max_words=10000)))
# Out:
# [[0.9611879 0.0388121]]

# %%
# Fake example #5

print(model.predict(preprocessor(["COVID-19 mRNA is actually not a vaccine at all, but rather an operating system that will convert our bodies into zombies."], maxlen=60, max_words=10000)))
# Out:
# [[0.98063135 0.01936869]]

# %%
# Real example #1

print(model.predict(preprocessor(["COVID-19 was the 3rd leading cause of death in the US in 2020, with heart disease and cancer being even deadlier."], maxlen=60, max_words=10000)))
# Out:
# [[0.9864965  0.01350354]]

# %%
# Real example #2

print(model.predict(preprocessor(["There is no evidence to back up the claim that COVID-19 increases the chances of women having miscarriages."], maxlen=60, max_words=10000)))
# Out:
# [[0.99835336 0.00164668]]

# %%
# Real example #3

print(model.predict(preprocessor(["People with cancer, kidney disease, lung diseases, dementia, diabetes, or liver disease are more likely to become seriously ill from COVID-19."], maxlen=60, max_words=10000)))
# Out:
# [[0.454971 0.545029]]

# %%
# Real example #4

print(model.predict(preprocessor(["Children have been impacted less harmfully by COVID infections, on average, than adults."], maxlen=60, max_words=10000)))
# Out:
# [[0.51612514 0.48387483]]

# %%
# Real example #5

print(model.predict(preprocessor(["People who have substance abuse problems are more likely to experience severe COVID-19 symtoms, if infected, than those who do not."], maxlen=60, max_words=10000)))
# Out:
# [[0.04058149 0.95941854]]

# %% [markdown]
# ## **Results:**
#
# ### The following analysis is based on the assumption that **0** corresponds to **real** and that **1** corresponds to **fake**:
#
# ### Since predicted probabilities for accuracy are rounded up for values greater than 0.5, and rounded down for values less than 0.5, the model correctly predicts all 5 of my fake tweets as being fake. However, it only correctly predicts 2 of my 5 real tweets (real examples #3 and #5) as being real. This corresponds to an overall model accuracy level of 70% - at least when tested on my "unseen" sample.
